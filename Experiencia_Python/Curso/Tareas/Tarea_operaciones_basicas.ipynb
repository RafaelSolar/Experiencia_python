# %% [markdown]
# #Ejercicio 1

# %%
45//6
# Out:
# 7

# %% [markdown]
# #Ejercicio 2

# %%
45%6
# Out:
# 3

# %% [markdown]
# #Ejercicio 3

# %%
10+20//7-2
# Out:
# 10

# %% [markdown]
# #Ejercicio 4

# %%
(9-(25+5-2)/(7*4))/2**3
# Out:
# 1.0

# %% [markdown]
# #Ejercicio 5

# %%
(2+2**3-2*(2-2**5)+2**2*2+2)/(2*(2*2-2**4)+2**2)
# Out:
# -4.0

# %% [markdown]
# #Ejercicio 6

# %%
0+6j-(4+1j)*2
# Out:
# (-8+4j)

# %% [markdown]
# #Ejercicio 7

# %%
(1+1j)/(1-1j)+(2+0j)/(-1+1j)
# Out:
# (-1+0j)

# %% [markdown]
# #ejercicio 8

# %%
(1+1j)**2
# Out:
# 2j

# %% [markdown]
# #ejercicio 9

# %%
abs((9-3j)/(-2-1j))
# Out:
# 4.242640687119285

# %% [markdown]
# #ejercicio 10

# %%
from cmath import phase
phase(0+1j)
# Out:
# 1.5707963267948966

# %%
2/(-1+1j)
# Out:
# (-1-1j)

# %%
(2+0j)/(-1+1j)
# Out:
# (-1-1j)
