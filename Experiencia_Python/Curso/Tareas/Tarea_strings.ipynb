# %% [markdown]
# #1

# %%
s1="Habia una vez, "
s2="un barquito chiquito "
s3="que no podia, "
s4="que no podia navegar."
print(s1+s2+s1+s2+s3*2+s4)
# Out:
# Habia una vez, un barquito chiquito Habia una vez, un barquito chiquito que no podia, que no podia, que no podia navegar

# %% [markdown]
# #2

# %%
print("Érase un hombre a una nariz pegado,\nÉrase una nariz superlativa,\nÉrase una alquitara medio viva,\nÉrase un peje espada mal barbado;")
# Out:
# Érase un hombre a una nariz pegado,
# Érase una nariz superlativa,
# Érase una alquitara medio viva,
# Érase un peje espada mal barbado;

# %% [markdown]
# #3

# %%
s="me encantan las matematicas"
print(s.upper())
# Out:
# ME ENCANTAN LAS MATEMATICAS

# %% [markdown]
# #4

# %%
s="Mi pasion por el chocolate es superior a mis fuerzas"
len(s)
# Out:
# 52

# %% [markdown]
# #5

# %%
s="Mi pasion por el chocolate es superior a mis fuerzas"
ini=s.find("chocolate")
fin=len("chocolate")
s_sub=s[ini:ini+fin]
print(s_sub)
# Out:
# chocolate

# %% [markdown]
# #6

# %%
nombre=input("Introduce tu nombre: ")
# Out:
# Introduce tu nombre: Rafael

# %% [markdown]
# #7

# %%
apellido=input("Introduce tu apellido: ")
# Out:
# Introduce tu apellido: Solar

# %% [markdown]
# #8

# %%
edad=int(input("Introduce tu edad: "))
# Out:
# Introduce tu edad: 23

# %% [markdown]
# #9

# %%
ciudad=input("Introduce la cidad donde vives: ")
# Out:
# Introduce la cidad donde vives: Puebla

# %% [markdown]
# #10

# %%
print("Su nombre es {} {}, tiene {} años y actualmente vive en {}.".format(nombre,apellido,edad,ciudad))
# Out:
# Su nombre es Rafael Solar, tiene 23 años y actualmente vive en Puebla.

# %% [markdown]
# Pirata :v
