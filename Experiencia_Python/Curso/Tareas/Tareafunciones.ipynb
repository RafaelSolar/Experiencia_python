# %% [markdown]
# #1

# %%
def divisoresn(n):
    """
    Funcion que obtiene los divisores de un entero positivo
    arg: n - numero entero positivo
    return: lista de divisores

    """
    divisors=[]
    n=int(n)
    if n<0:
        print("El numero {} es negativo".format(n))
        return
    elif n==0:
        print("El numero es cero, por lo tanto tiene infinitos divisores")
        return
    for i in range(1,n+1):
        if n % i == 0:
            divisors.append(i)
    
    print("Estos son los divisores: ")
    return divisors
divisoresn(245)
# Out:
# Estos son los divisores:
# [1, 5, 7, 35, 49, 245]

# %% [markdown]
# #2

# %%
def helper_nummayor(n,m,resl):
    print("El numero {} es {} que {}.".format(n,resl,m))

def nummayor(n,m):
    """
    Dado dos reales obtiene el mayor

    Args:
    n (real): valor 1
    m (real): valor 2

    Returns: 
    el valor mayor
    """
    if n > m:
        resl= "mayor"   
        helper_nummayor(n,m,resl)
        return n
    elif n < m:
        resl= "mayor"
        helper_nummayor(m,n,resl)
        return m
    else:
        resl= "igual"
        helper_nummayor(m,n,resl)
        return

nummayor(2.99,2.56)
nummayor(-56.56,-1.27)
nummayor(9,9)
# Out:
# El numero 2.99 es mayor que 2.56.
# El numero -1.27 es mayor que -56.56.
# El numero 9 es igual que 9.

# %% [markdown]
# #3

# %%
def helper_valorabs(n,m):
    print("El valor absoluto de {} es {}.".format(n,m))

def valorabs(n):
    """
    Dado un numero obtiene su valor absoluto

    Args:
    n (real): Numero dado

    Returns: 
    El valor absoluto
    """
    helper_valorabs(n,abs(n))
    return abs(n)

valorabs(59.56)
valorabs(0)
valorabs(-78.05)
# Out:
# El valor absoluto de 59.56 es 59.56.
# El valor absoluto de 0 es 0.
# El valor absoluto de -78.05 es 78.05.
# 78.05

# %% [markdown]
# #4

# %%
def detectorvocal(c):
    """
    Dado un caracter detecta si es una vocal

    Args:
    c (caracter): caracter introducido

    Returns: 
    True si es una vocal, false si no lo es
    """
    if len(c)>1:
        print("Introduciste más de una letra.")
        return
    if c == ("a" or "e" or "i" or "o" or "u"):
        return True
    else:
        return False

c=str(input("Introduce una letra: "))
detectorvocal(c)
# Out:
# Introduce una letra: a
# True

# %% [markdown]
# #5

# %%
def divisoresn(n):
    """
    Funcion que obtiene los divisores de un entero positivo
    arg: n - numero entero positivo
    return: lista de divisores

    """
    divisors=[]
    for i in range(1,n+1):
        if n % i == 0:
            divisors.append(i)
    return divisors

def calcularMCD(n,m):
    """
    Funcion que obtiene el maximo comun divisor (MCD)
    arg: n - numero entero positivo
         m - numero entero positivo
    return: MCD

    """
    if (n <= 0 or m <=0):
        print("Alguno numero o ambos son negativos o cero")
        return

    n , m= int(n) , int(m)
    divisorn=set(divisoresn(n))
    divisorm=set(divisoresn(m))
    interseccion= list(divisorn & divisorm)

    max=-9999

    for i in interseccion:
        if i>max:
            max=i
        else:
            continue
    
    return max

n, m= 1032, 180
MCD = calcularMCD(n,m)

print("El maximo comun denominador de {} y {} es: {}".format(n,m,MCD))
# Out:
# El maximo comun denominador de 1032 y 180 es: 12

# %% [markdown]
# #6

# %%
def calcularMCM(n,m):
    """
    Funcion que obtiene el minimo comun multiplo (MCM)
    arg: n - numero entero positivo
         m - numero entero positivo
    return: MCM

    """   
    if (n <= 0 or m <=0):
        print("Alguno numero o ambos son negativos o cero")
        return
    n , m= int(n) , int(m)
    MCD = calcularMCD(n,m)
    MCM = (n*m)/MCD

    return MCM

n, m= 1032, 180
MCM = calcularMCM(n,m)
print("El minimo comun multiplo de {} y {} es: {}".format(n,m,MCM))
# Out:
# El minimo comun multiplo de 1032 y 180 es: 15480.0

# %% [markdown]
# #7

# %%
def confpalindromo(s):
    """
    Funcion que comprueba si una palabra es un palindromo
    arg: s - palabra 
    return: True si es un palindromo, false si no es palindromo
    
    """ 
    s=s.lower()
    lword, lwordrev = [], [] 
    for i in range(0,len(s)):
        lword.append(s[i])
        lwordrev.append(s[(i*-1)-1])
    resl=lword == lwordrev

    return resl
    
confpalindromo("Malayalam")
# Out:
# True

# %% [markdown]
# #8

# %%
def HEXtoRGB(hexnum):

    red, green, blue = hexnum[0:2], hexnum[2:4], hexnum[4:6]

    red, green, blue = int(red,16), int(green,16), int(blue,16)

    return [red, green, blue]
    
HEXtoRGB("ff48F1")
# Out:
# [255, 72, 241]

# %%
hex(54)
int("FF",16)
# Out:
# 255

# %% [markdown]
# #9

# %%
def diccparimpar(listaword):
    par,impar=0,0
    for elem in listaword:
        if len(elem) % 2 == 0:
            par +=1
        else:
            impar +=1
    diccresul={"Par":par , "Impar":impar}
    return diccresul

diccparimpar(["pato","Araña", "Elefante", "Rata", "Hormiga", "Abejas"])
# Out:
# {'Impar': 2, 'Par': 4}

# %% [markdown]
# #10

# %%
def ocurrienciasletras(s):
    s=s.lower()
    num=0
    diccount= {}
    for c in s:
        num = s.count(c)
        diccount[c]=num

    return diccount

ocurrienciasletras("El papel es un instrumento importante para la escuela.")
# Out:
# {' ': 8,
#  '.': 1,
#  'a': 6,
#  'c': 1,
#  'e': 7,
#  'i': 2,
#  'l': 4,
#  'm': 2,
#  'n': 4,
#  'o': 2,
#  'p': 4,
#  'r': 3,
#  's': 3,
#  't': 4,
#  'u': 3}

# %%
def VerticesSquare(P = [0, 1], l = 2):
    
    vertices = []
    vertices.append(P)
    # Añade el segundo vértice
    vertices.append([P[0]+l,P[1]])
    # Añade el tercer vértice
    vertices.append([P[0]+l,P[1]+l])
    # Añade el cuarto vértice
    vertices.append([P[0],P[1]+l])
    return vertices

VerticesSquare()
# Out:
# [[0, 1], [2, 1], [2, 3], [0, 3]]
