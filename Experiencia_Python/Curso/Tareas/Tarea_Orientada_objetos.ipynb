# %% [markdown]
# #1

# %%
x = list(range(0,50+1))
len(x)
# Out:
# 51

# %%
class Date():

    def __init__(self,day = 1 ,month = 1 ,year = 1):
        self.day = day
        self.month = month
        self.year = year

# %% [markdown]
# #2

# %%
def num_ceros(cifra,ceros=0):
    """
    Esta funcion devuelve una string
    arg: cifra es el numero al cual le queremos adjuntar los ceros a la izauierda
         ceros es la cantidad de ceros a la izquierda que queremos
    return: una string con la cantidad de ceros a la izquierda que deseamos
    """
    num_ceros = "0"*ceros
    return (num_ceros + str(cifra))


class Date():
    def __init__(self,day = 1,month = 1,year = 1):
        self.day = day
        self.month = month
        self.year = year
    

    def __str__(self):
        ceros = 0
        if self.year < 10:
            ceros = 3
        elif self.year < 100:
            ceros = 2
        elif self.year < 1000:
            ceros = 1
        return ("{} / {} / {}".format( num_ceros(self.day) if self.day >= 10 else num_ceros(self.day , 1) , num_ceros(self.month) if self.month >= 10 else num_ceros(self.month , 1) , num_ceros(self.year , ceros)))
fecha = Date(9,8,999)
print(fecha)
# Out:
# 09 / 08 / 0999

# %% [markdown]
# #3

# %%
def num_ceros(cifra,ceros=0):
    """
    Esta funcion devuelve una string
    arg: cifra es el numero al cual le queremos adjuntar los ceros a la izauierda
         ceros es la cantidad de ceros a la izquierda que queremos
    return: una string con la cantidad de ceros a la izquierda que deseamos
    """
    num_ceros = "0"*ceros
    return (num_ceros + str(cifra))


class Date():
    def __init__(self,day = 1,month = 1,year = 1):
        self.day = day
        self.month = month
        self.year = year
    
    def isLeap(self):
        if self.year % 4 == 0:
            return True
        else:
            return False

    def __str__(self):
        ceros = 0
        if self.year < 10:
            ceros = 3
        elif self.year < 100:
            ceros = 2
        elif self.year < 1000:
            ceros = 1
        return ("{} / {} / {}".format( num_ceros(self.day) if self.day >= 10 else num_ceros(self.day , 1) , num_ceros(self.month) if self.month >= 10 else num_ceros(self.month , 1) , num_ceros(self.year , ceros)))
fecha = Date(9,8,1948)

fecha.isLeap()
# Out:
# True

# %% [markdown]
# #4

# %%
def num_ceros(cifra,ceros=0):
    """
    Esta funcion devuelve una string
    arg: cifra es el numero al cual le queremos adjuntar los ceros a la izauierda
         ceros es la cantidad de ceros a la izquierda que queremos
    return: una string con la cantidad de ceros a la izquierda que deseamos
    """
    num_ceros = "0"*ceros
    return (num_ceros + str(cifra))


class Date():
    
    def __init__(self,day = 1,month = 1,year = 1):

        if self.__validDate(day, month, year):
            self.day = day
            self.month = month
            self.year = year
        else:
            return print("¡¡¡La fecha introducida no es una fecha válida!!!")

    def __validDate(self,dayv,monthv,yearv):
        isValid = True
        if ((dayv <= 0 or dayv > 31) or (monthv <=0 or monthv > 12) or yearv <=0) or ( float == type(dayv) or float == type(monthv) or float == type(yearv)):
            isValid = False
            return isValid
        else:
            return isValid

    def isLeap(self):
        if self.year % 4 == 0:
            return True
        else:
            return False

    
    def totalMonthdays(self, isLeapFeb = False):
        if isLeapFeb:
            FebLeap = 29
        else:
            FebLeap = 28
        dicc_months={ 1 : ["Enero",31] , 2 : ["Febrero", FebLeap], 3 : ["Marzo",31] , 4 : ["Abril", 30],
                      5 : ["Mayo",31] , 6 : ["Junio", 30], 7 : ["Julio",31] , 8 : ["Agosto", 31],
                      9 : ["Septiembre",30] , 10 : ["Octubre", 31], 11 : ["Noviembre",30] , 12 : ["Diciembe", 31],
                    }
        return print("El mes de {} tiene {} días".format(dicc_months[self.month][0], dicc_months[self.month][1]))


    def __str__(self):
        ceros = 0
        if self.year < 10:
            ceros = 3
        elif self.year < 100:
            ceros = 2
        elif self.year < 1000:
            ceros = 1
        return ("{} / {} / {}".format( num_ceros(self.day) if self.day >= 10 else num_ceros(self.day , 1) , num_ceros(self.month) if self.month >= 10 else num_ceros(self.month , 1) , num_ceros(self.year , ceros)))

fecha = Date(31,-1,1948)
# Out:
# ¡¡¡La fecha introducida no es una fecha válida!!!

# %%
fecha1 = Date(12, 2 , 1948)
fecha1.totalMonthdays()
# Out:
# El mes de Febrero tiene 28 días

# %% [markdown]
# #5

# %%
def num_ceros(cifra,ceros=0):
    """
    Esta funcion devuelve una string
    arg: cifra es el numero al cual le queremos adjuntar los ceros a la izauierda
         ceros es la cantidad de ceros a la izquierda que queremos
    return: una string con la cantidad de ceros a la izquierda que deseamos
    """
    num_ceros = "0"*ceros
    return (num_ceros + str(cifra))


class Date():
    
    def __init__(self,day = 1,month = 1,year = 1):

        if self.__validDate(day, month, year):
            self.day = day
            self.month = month
            self.year = year
        else:
            return print("¡¡¡La fecha introducida no es una fecha válida!!!")

    def __validDate(self,dayv,monthv,yearv):
        isValid = True
        if ((dayv <= 0 or dayv > 31) or (monthv <=0 or monthv > 12) or yearv <=0) or ( float == type(dayv) or float == type(monthv) or float == type(yearv)):
            isValid = False
            return isValid
        else:
            return isValid

    def isLeap(self):
        if self.year % 4 == 0:
            return True
        else:
            return False

    
    def totalMonthdays(self, isLeapFeb = False):
        if isLeapFeb:
            FebLeap = 29
        else:
            FebLeap = 28
        dicc_months={ 1 : ["Enero",31] , 2 : ["Febrero", FebLeap], 3 : ["Marzo",31] , 4 : ["Abril", 30],
                      5 : ["Mayo",31] , 6 : ["Junio", 30], 7 : ["Julio",31] , 8 : ["Agosto", 31],
                      9 : ["Septiembre",30] , 10 : ["Octubre", 31], 11 : ["Noviembre",30] , 12 : ["Diciembe", 31],
                    }
        return print("El mes de {} tiene {} días".format(dicc_months[self.month][0], dicc_months[self.month][1]))

    @property
    def monthName(self):
        dicc_months_english={ 1 : "January" , 2 : "Febrary", 3 : "March" , 4 : "April",
                      5 : "May" , 6 : "June", 7 : "July" , 8 : "August",
                      9 : "September" , 10 : "October", 11 : "November" , 12 : "December" }
        return dicc_months_english[self.month]

    def __str__(self):
        ceros = 0
        if self.year < 10:
            ceros = 3
        elif self.year < 100:
            ceros = 2
        elif self.year < 1000:
            ceros = 1
        return ("{} / {} / {}".format( num_ceros(self.day) if self.day >= 10 else num_ceros(self.day , 1) , num_ceros(self.month) if self.month >= 10 else num_ceros(self.month , 1) , num_ceros(self.year , ceros)))

fecha1 = Date(12, 8, 1987)
fecha1.monthName
# Out:
# 'August'

# %% [markdown]
# #6

# %%
def num_ceros(cifra,ceros=0):
    """
    Esta funcion devuelve una string
    arg: cifra es el numero al cual le queremos adjuntar los ceros a la izauierda
         ceros es la cantidad de ceros a la izquierda que queremos
    return: una string con la cantidad de ceros a la izquierda que deseamos
    """
    num_ceros = "0"*ceros
    return (num_ceros + str(cifra))

def helper_isLater(day1,month1,year1,day2,month2,year2,flag):
    return print("La fecha {}/{}/{}{} es posteior a {}/{}/{}".format(day1,month1,year1, 
                                                                     "" if flag else " no", day2,month2,year2))

def helper_isPrevius(day1,month1,year1,day2,month2,year2,flag):
    return print("La fecha {}/{}/{}{} es anterior a {}/{}/{}".format(day1,month1,year1, 
                                                                     "" if flag else " no", day2,month2,year2)) 



class Date():
    
    def __init__(self,day = 1,month = 1,year = 1):

        if self.__validDate(day, month, year):
            self.day = day
            self.month = month
            self.year = year
        else:
            return print("¡¡¡La fecha introducida no es una fecha válida!!!")

    def __validDate(self,dayv,monthv,yearv):
        isValid = True
        if ((dayv <= 0 or dayv > 31) or (monthv <=0 or monthv > 12) or yearv <=0) or ( float == type(dayv) or float == type(monthv) or float == type(yearv)):
            isValid = False
            return isValid
        else:
            return isValid

    def isLeap(self):
        if self.year % 4 == 0:
            return True
        else:
            return False

    
    def totalMonthdays(self, isLeapFeb = False):
        if isLeapFeb:
            FebLeap = 29
        else:
            FebLeap = 28
        dicc_months={ 1 : ["Enero",31] , 2 : ["Febrero", FebLeap], 3 : ["Marzo",31] , 4 : ["Abril", 30],
                      5 : ["Mayo",31] , 6 : ["Junio", 30], 7 : ["Julio",31] , 8 : ["Agosto", 31],
                      9 : ["Septiembre",30] , 10 : ["Octubre", 31], 11 : ["Noviembre",30] , 12 : ["Diciembe", 31],
                    }
        return print("El mes de {} tiene {} días".format(dicc_months[self.month][0], dicc_months[self.month][1]))

    @property
    def monthName(self):
        dicc_months_english={ 1 : "January" , 2 : "Febrary", 3 : "March" , 4 : "April",
                      5 : "May" , 6 : "June", 7 : "July" , 8 : "August",
                      9 : "September" , 10 : "October", 11 : "November" , 12 : "December" }
        return dicc_months_english[self.month]

    @staticmethod
    def areEqual(fecha_1 , fecha_2):
        isEqual = False
        if ((fecha_1.day == fecha_2.day) and (fecha_1.month == fecha_2.month) and (fecha_1.year == fecha_2.year)):
            print("La fechas fechas son iguales")
            isEqual = True
            return isEqual
        else:
            print("Las fechas no son iguales")
            return isEqual
    @staticmethod
    def isLater(fecha_1 , fecha_2):
        if (fecha_1.year < fecha_2.year):
            return helper_isLater(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif (fecha_1.month < fecha_2.month):
            return helper_isLater(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif (fecha_1.day < fecha_2.day):
            return helper_isLater(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif ((fecha_1.day == fecha_2.day) and (fecha_1.month == fecha_2.month) and (fecha_1.year == fecha_2.year)):
            return helper_isLater(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        else:
            return helper_isLater(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,True)

    @staticmethod
    def isPrevius(fecha_1 , fecha_2):
        if (fecha_1.year > fecha_2.year):
            return helper_isPrevius(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif (fecha_1.month > fecha_2.month):
            return helper_isPrevius(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif (fecha_1.day > fecha_2.day):
            return helper_isPrevius(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif ((fecha_1.day == fecha_2.day) and (fecha_1.month == fecha_2.month) and (fecha_1.year == fecha_2.year)):
            return helper_isPrevius(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        else:
            return helper_isPrevius(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,True)

    def __str__(self):
        ceros = 0
        if self.year < 10:
            ceros = 3
        elif self.year < 100:
            ceros = 2
        elif self.year < 1000:
            ceros = 1
        return ("{} / {} / {}".format( num_ceros(self.day) if self.day >= 10 else num_ceros(self.day , 1) , num_ceros(self.month) if self.month >= 10 else num_ceros(self.month , 1) , num_ceros(self.year , ceros)))

# %%
fecha1=Date(30,8,2022)
fecha2=Date(30,8,2022)
Date.areEqual(fecha1,fecha2)
Date.isLater(fecha1,fecha2)
Date.isPrevius(fecha1,fecha2)
# Out:
# La fechas fechas son iguales
# La fecha 30/8/2022 no es posteior a 30/8/2022
# La fecha 30/8/2022 no es anterior a 30/8/2022

# %% [markdown]
# #7

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-489cee82aacc> in <module>()
#       1 for row in words.itertuples():
# ----> 2     print("La palabra {} tiene {} letras, de las cuales {} son son vocales y {} son consonantes.".format(row["words"],row[2],row[3],row[4]))
#
# TypeError: tuple indices must be integers or slices, not str

# %% [markdown]
# #8

# %%
import random 


def num_ceros(cifra,ceros=0):
    """
    Esta funcion devuelve una string
    arg: cifra es el numero al cual le queremos adjuntar los ceros a la izauierda
         ceros es la cantidad de ceros a la izquierda que queremos
    return: una string con la cantidad de ceros a la izquierda que deseamos
    """
    num_ceros = "0"*ceros
    return (num_ceros + str(cifra))

def helper_isLater(day1,month1,year1,day2,month2,year2,flag):
    return print("La fecha {}/{}/{}{} es posteior a {}/{}/{}".format(day1,month1,year1, 
                                                                     "" if flag else " no", day2,month2,year2))

def helper_isPrevius(day1,month1,year1,day2,month2,year2,flag):
    return print("La fecha {}/{}/{}{} es anterior a {}/{}/{}".format(day1,month1,year1, 
                                                                     "" if flag else " no", day2,month2,year2)) 



class Date():
    
    def __init__(self,day = 1,month = 1,year = 1):

        if self.__validDate(day, month, year):
            self.day = day
            self.month = month
            self.year = year
        else:
            return print("¡¡¡La fecha introducida no es una fecha válida!!!")

    def __validDate(self,dayv,monthv,yearv):
        isValid = True
        if ((dayv <= 0 or dayv > 31) or (monthv <=0 or monthv > 12) or yearv <=0) or ( float == type(dayv) or float == type(monthv) or float == type(yearv)):
            isValid = False
            return isValid
        else:
            return isValid

    def isLeap(self):
        if self.year % 4 == 0:
            return True
        else:
            return False

    
    def totalMonthdays(self, isLeapFeb = False):
        if isLeapFeb:
            FebLeap = 29
        else:
            FebLeap = 28
        dicc_months={ 1 : ["Enero",31] , 2 : ["Febrero", FebLeap], 3 : ["Marzo",31] , 4 : ["Abril", 30],
                      5 : ["Mayo",31] , 6 : ["Junio", 30], 7 : ["Julio",31] , 8 : ["Agosto", 31],
                      9 : ["Septiembre",30] , 10 : ["Octubre", 31], 11 : ["Noviembre",30] , 12 : ["Diciembe", 31],
                    }
        return print("El mes de {} tiene {} días".format(dicc_months[self.month][0], dicc_months[self.month][1]))

    @property
    def monthName(self):
        dicc_months_english={ 1 : "January" , 2 : "Febrary", 3 : "March" , 4 : "April",
                      5 : "May" , 6 : "June", 7 : "July" , 8 : "August",
                      9 : "September" , 10 : "October", 11 : "November" , 12 : "December" }
        return dicc_months_english[self.month]

    @staticmethod
    def areEqual(fecha_1 , fecha_2):
        isEqual = False
        if ((fecha_1.day == fecha_2.day) and (fecha_1.month == fecha_2.month) and (fecha_1.year == fecha_2.year)):
            print("La fechas fechas son iguales")
            isEqual = True
            return isEqual
        else:
            print("Las fechas no son iguales")
            return isEqual
    @staticmethod
    def isLater(fecha_1 , fecha_2):
        if (fecha_1.year < fecha_2.year):
            return helper_isLater(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif (fecha_1.month < fecha_2.month):
            return helper_isLater(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif (fecha_1.day < fecha_2.day):
            return helper_isLater(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif ((fecha_1.day == fecha_2.day) and (fecha_1.month == fecha_2.month) and (fecha_1.year == fecha_2.year)):
            return helper_isLater(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        else:
            return helper_isLater(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,True)

    @staticmethod
    def isPrevius(fecha_1 , fecha_2):
        if (fecha_1.year > fecha_2.year):
            return helper_isPrevius(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif (fecha_1.month > fecha_2.month):
            return helper_isPrevius(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif (fecha_1.day > fecha_2.day):
            return helper_isPrevius(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        elif ((fecha_1.day == fecha_2.day) and (fecha_1.month == fecha_2.month) and (fecha_1.year == fecha_2.year)):
            return helper_isPrevius(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,False)
        else:
            return helper_isPrevius(fecha_1.day,fecha_1.month,fecha_1.year,fecha_2.day,fecha_2.month,fecha_2.year,True)

    @classmethod
    def firstDayOfTheYear(cls):
        yearfd = int(input("Introduce un año: "))
        return cls(day=1 , month = 1, year = yearfd)
    
    @classmethod
    def lastDayOfTheYear(cls):
        yearld = int(input("Introduce un año: "))
        return cls(day = 31, month = 12 , year = yearld )
        
        

    def plusday(self):
        dayn , monthn, yearn = self.day , self.month, self.year
        if (dayn == 31 and monthn == 12):
            self.day, self.month, self.year = 1,1, yearn + 1
        elif (dayn == 31 and monthn in [1,3,5,7,8,10]) or (dayn == 30 and monthn in [4,6,9,11]):
            self.day , self.month = 1 , monthn + 1
        elif (dayn == 29 and monthn == 2 and self.isLeap()):
            self.day , self.month = 1 , monthn + 1    
        elif (dayn == 28 and monthn == 2 and not self.isLeap()):
            self.day , self.month = 1 , monthn + 1             
        else:
            self.day += 1
    
    def minusday(self):
        dayn , monthn, yearn = self.day , self.month, self.year
        if (dayn == 1 and monthn == 1):
            self.day, self.month, self.year = 31,12, yearn - 1
        elif (dayn == 1 and monthn in [2,4,6,8,9,11]):
            self.day , self.month = 31 , monthn - 1
        elif (dayn == 1 and monthn in [5,7,10,12]):
            self.day , self.month = 30 , monthn - 1
        elif (dayn == 1 and monthn == 3 and self.isLeap()):
            self.day , self.month = 29 , monthn - 1    
        elif (dayn == 1 and monthn == 3 and not self.isLeap()):
            self.day , self.month = 28 , monthn - 1             
        else:
            self.day -= 1  
    
    @classmethod  
    def copy(cls, fecha):
        dia,mes,yearcopy=fecha.day,fecha.month,fecha.year
        return cls(day = dia, month = mes , year = yearcopy)

    @staticmethod
    def difference(fecha1,fecha2):
        diffday = fecha2.day - fecha1.day
        diffmonth = fecha2.month - fecha1.month
        diffyear = fecha2.year - fecha1.year
        if diffday <0:
            diffday = -1*diffday
        if diffmonth <0:
            diffmonth = -1*diffmonth
        if diffyear <0:
            diffyear = -1*diffyear
        return ("La diferencia de días es: {} días.".format(diffday+diffmonth*30+diffyear*365))


    @classmethod
    def ramdomdate(cls):
        dayr = random.randrange(1, 31)
        monthr = random.randrange(1, 13)
        yearr = random.randrange(1, 9999)

        return cls(day =dayr,month = monthr, year = yearr)
    @classmethod
    def todate(cls,fechastr):
        fecha = fechastr.split(" ")

        dicc_months_english={ "january" : 1, "febrary":2,  "march" :3, "april":4,
                       "may" :5, "june":6 , "july": 7,"august" : 8,
                      "september" :9,  "october":10 , "november" :11, "december" :12}
        clavemes = fecha[1].lower()
        mes = dicc_months_english[clavemes]
        return cls(day = int(fecha[0]),month = mes, year = int(fecha[2]))


    def __str__(self):
        ceros = 0
        if self.year < 10:
            ceros = 3
        elif self.year < 100:
            ceros = 2
        elif self.year < 1000:
            ceros = 1
        return ("{} / {} / {}".format( num_ceros(self.day) if self.day >= 10 else num_ceros(self.day , 1) , num_ceros(self.month) if self.month >= 10 else num_ceros(self.month , 1) , num_ceros(self.year , ceros)))

print(Date.todate("05 July 1985"))
# Out:
# 05 / 07 / 1985

# %% [markdown]
# #9

# %%
# Out:
#       words  length  vowels  consonats
# 9  boutique       8       5          3
# 8   hazañas       7       3          4
# 4    cicuta       6       3          3
# 5    fatiga       6       3          3
# 6    nachos       6       2          4
# 7    jadeos       6       3          3
# 2     algas       5       2          3
# 3     broma       5       2          3
# 0      euro       4       3          1
# 1      diez       4       2          2

# %%
# Out:
#       words  length  vowels  consonats
# 9  boutique       8       5          3
# 8   hazañas       7       3          4
# 4    cicuta       6       3          3
# 5    fatiga       6       3          3
# 6    nachos       6       2          4
# 7    jadeos       6       3          3
# 2     algas       5       2          3
# 3     broma       5       2          3
# 0      euro       4       3          1
# 1      diez       4       2          2

# %% [markdown]
# #10

# %%
# Out:
# [5, 3, 3, 3, 3, 3, 2, 2, 2, 2]
