# %%
import math as mt

# %%
print("{}, {}, {}".format(mt.log2(1), mt.log10(1),mt.log(1,100)))
print("{}, {}, {}".format(mt.log2(2),mt.log10(10),mt.log(55,55)))
print("{} = {}, {} = {}, {} = {}".format(mt.log2(10**5) , 5*mt.log2(10), mt.log10(1.5**8) , 8*mt.log10(1.5), mt.log(5.6**9,4.4) , 9*mt.log(5.6,4.4) ))
print("{} = {}, {} = {}, {} = {}".format(mt.log2(mt.pow(10, 1/4 )) , (1/4)*mt.log2(10), mt.log10(mt.pow(7.4, 3/7)) , (3/7)*mt.log10(7.4), mt.log(mt.pow(7.9,7/18),4.4) , (7/18)*mt.log(7.9,4.4) ))
print("{} = {}, {} = {}, {} = {}".format(mt.log2(7*0.14) , mt.log2(7)+ mt.log2(0.14) , mt.log10(45.9*7.5), mt.log10(45.9)+mt.log10(7.5), mt.log(8*4 , 4.7), mt.log(8,4.7)+mt.log(4,4.7)))
print("{} = {}, {} = {}, {} = {}".format(mt.log2(7/0.14) , mt.log2(7)- mt.log2(0.14) , mt.log10(45.9/7.5), mt.log10(45.9)-mt.log10(7.5), mt.log(8/4 , 4.7), mt.log(8,4.7)-mt.log(4,4.7)))
print("{} = {}, {} = {}, {} = {}".format(mt.log2(7) , (mt.log10(7)/mt.log10(2)) , mt.log10(45.9), (mt.log2(45.9)/mt.log2(10)) , mt.log(8.4 , 4.7), (mt.log(8.4 , 5.9)/mt.log(4.7,5.92))))
# Out:
# 0.0, 0.0, 0.0
# 1.0, 1.0, 1.0
# 16.609640474436812 = 16.609640474436812, 1.40873007244545 = 1.40873007244545, 10.464937809921986 = 10.464937809921988
# 0.8304820237218405 = 0.8304820237218405, 0.37252787988470404 = 0.3725278798847041, 0.5425064109994395 = 0.5425064109994395
# -0.02914634565951635 = -0.02914634565951646, 2.536873948928961 = 2.536873948928961, 2.239480397903404 = 2.2394803979034035
# 5.643856189774724 = 5.643856189774725, 0.7867514221455612 = 0.7867514221455612, 0.44789607958068073 = 0.4478960795806807
# 2.807354922057604 = 2.807354922057604, 1.6618126855372612 = 1.6618126855372612, 1.3752153427489184 = 1.3778373080466928

# %%
def degree_to_rad(x = 0.):
    from math import pi
    mult = x//360.
    if mult>0:
        return ((x-360*mult)*pi)/180
    return (x*pi)/180

def rad_to_degree(x =0.):
    from math import tau
    mult = x // tau
    if mult > 0:
        return ((x-mult*tau)*180)/(tau/2.)
    return (x*180)/(tau/2.)

print("Comprovacion de grados a radianes:\nFuncion creada : {} , Funcion math: {}".format(degree_to_rad(450), mt.radians(90)))
print()
print("Comprovacion de radianes a grados:\nFuncion creada : {} , Funcion math: {}".format(rad_to_degree(3*mt.pi), mt.degrees(mt.pi)))
# Out:
# Comprovacion de grados a radianes:
# Funcion creada : 1.5707963267948966 , Funcion math: 1.5707963267948966
#
# Comprovacion de radianes a grados:
# Funcion creada : 180.0 , Funcion math: 180.0

# %%
print("Primero: sin^2({}) + cos^2({}) = {}".format(45,45, mt.pow(mt.sin(45),2) + mt.pow(mt.cos(45),2) ))
print()
print("tan({}) = sin({})/cos({})".format(89,89,89))
print("tan({}) = {}".format(89, mt.tan(89)))
print("sin({})/cos({}) = {}".format(89,89, mt.sin(89)/mt.cos(89)))
# Out:
# Primero: sin^2(45) + cos^2(45) = 1.0
#
# tan(89) = sin(89)/cos(89)
# tan(89) = 1.6858253705060158
# sin(89)/cos(89) = 1.6858253705060158

# %%
mt.isinf(1544/0.1e-3000)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-55-42098d4d15e0> in <module>()
#       1
# ----> 2 mt.isinf(1544/0.1e-3000)
#
# ZeroDivisionError: float division by zero

# %%
def choose(n, k):
  import math
  if (n >= k and k >= 0):
    return math.factorial(n) / (math.factorial(k) * math.factorial(n - k))
  else:
    return "No se puede calcular el número factorial indicado"

choose(15,3)
# Out:
# 455.0

# %%
import cmath as cmt 

xcr = complex(1,-1)
xcp = cmt.polar(xcr)
print(xcp)
# Out:
# (1.4142135623730951, -0.7853981633974483)

# %%
z = complex(1 , 8.5)
ez = cmt.exp(z)
ezm = cmt.exp(-z) 
print("senh({}) = {} , (e^z - e^-z)/2 = {}".format(z,cmt.sinh(z) , (ez - ezm)/2))
print()
print("cosh({}) = {} , (e^z + e^-z)/2 = {}".format(z,cmt.cosh(z) , (ez + ezm)/2))
# Out:
# senh((1+8.5j)) = (-0.7074851066229807+1.2321300006388463j) , (e^z - e^-z)/2 = (-0.7074851066229807+1.2321300006388463j)
#
# cosh((1+8.5j)) = (-0.9289529089612304+0.9383830078643182j) , (e^z + e^-z)/2 = (-0.9289529089612304+0.9383830078643182j)

# %%
z = complex(0.5 , 8)
print("sinh(-{}) = {} , -sinh({}) = {} ".format(z,cmt.sinh(-z),z,-cmt.sinh(z)))
print()
print("cosh(-{}) = {} , cosh({}) = {} ".format(z,cmt.cosh(-z),z,cmt.cosh(z)))
# Out:
# sinh(-(0.5+8j)) = (0.07581938456685004-1.1156260477835833j) , -sinh((0.5+8j)) = (0.07581938456685004-1.1156260477835833j)
#
# cosh(-(0.5+8j)) = (-0.16406961606099887+0.5155499377669694j) , cosh((0.5+8j)) = (-0.16406961606099887+0.5155499377669694j)

# %%
for i in range(-10,11):
    print("tan({}pi) = {}".format(i,mt.tan(i*mt.pi)))
# Out:
# tan(-10pi) = 1.2246467991473533e-15
# tan(-9pi) = 1.102182119232618e-15
# tan(-8pi) = 9.797174393178826e-16
# tan(-7pi) = 8.572527594031472e-16
# tan(-6pi) = 7.347880794884119e-16
# tan(-5pi) = 6.123233995736766e-16
# tan(-4pi) = 4.898587196589413e-16
# tan(-3pi) = 3.6739403974420594e-16
# tan(-2pi) = 2.4492935982947064e-16
# tan(-1pi) = 1.2246467991473532e-16
# tan(0pi) = 0.0
# tan(1pi) = -1.2246467991473532e-16
# tan(2pi) = -2.4492935982947064e-16
# tan(3pi) = -3.6739403974420594e-16
# tan(4pi) = -4.898587196589413e-16
# tan(5pi) = -6.123233995736766e-16
# tan(6pi) = -7.347880794884119e-16
# tan(7pi) = -8.572527594031472e-16
# tan(8pi) = -9.797174393178826e-16
# tan(9pi) = -1.102182119232618e-15
# tan(10pi) = -1.2246467991473533e-15

# %%
print("{}^{} * {}^{} = {} , {}^({}+{}) = {}".format(8,2,8,5, mt.pow(8,2) * mt.pow(8,5), 8,2,5 ,  mt.pow(8,2+5)  ))
print("{}^{} * {}^{} = {} , {}^({}+{}) = {}".format(5.5,4,5.5,1, mt.pow(5.5,4) * mt.pow(5.5,1), 5.5,4,1 ,  mt.pow(5.5,4+1)  ))
print("{}^{} * {}^{} = {} , {}^({}+{}) = {}".format(8.9,2,8.9,5, mt.pow(8.9,2) * mt.pow(8.9,5), 8.9,2,8 ,  mt.pow(8.9,2+5)  ))
# Out:
# 8^2 * 8^5 = 2097152.0 , 8^(2+5) = 2097152.0
# 5.5^4 * 5.5^1 = 5032.84375 , 5.5^(4+1) = 5032.84375
# 8.9^2 * 8.9^5 = 4423133.489552901 , 8.9^(2+8) = 4423133.489552901
